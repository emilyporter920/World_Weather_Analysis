# %%
# Import dependencies
import pandas as pd
import gmaps
import requests
import numpy as np
import matplotlib.pyplot as plt

# Import the API key
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations (2,000 of them)
lats=np.random.uniform(low=-90.000, high=90.000, size=2000)

lngs=np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs=zip(lats,lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding all cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 772

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b25b2213ff10b5096dd673b31010f0a4

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1 
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_des = city_weather['weather'][0]['description']
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_des})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | upernavik
# Processing Record 2 of Set 1 | jaguarao
# Processing Record 3 of Set 1 | chokurdakh
# Processing Record 4 of Set 1 | kallaste
# Processing Record 5 of Set 1 | pasni
# Processing Record 6 of Set 1 | butaritari
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | grindavik
# Processing Record 9 of Set 1 | tiksi
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | severo-kurilsk
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | ahipara
# Processing Record 15 of Set 1 | imbituba
# Processing Record 16 of Set 1 | polson
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 1 | provideniya
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | nouadhibou
# Processing Record 23 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | mitsamiouli
# Processing Record 26 of Set 1 | itarema
# Processing Record 27 of Set 1 | guapore
# Processing Record 28 of Set 1 | grand gaube
# Processing Record 29 of Set 1 | torbay
# Processing Record 30 of Set 1 | sambava
# Processing Record 31 of Set 1 | guerrero negro
# Processing Record 32 of Set 1 | nikolskoye
# Processing Record 33 of Set 1 | bida
# Processing Record 34 of Set 1 | funtua
# Processing Record 35 of Set 1 | saint-pierre
# Processing Record 36 of Set 1 | manzil tamim
# City not found. Skipping...
# Processing Record 37 of Set 1 | bambous virieux
# Processing Record 38 of Set 1 | mucurapo
# Processing Record 39 of Set 1 | kavieng
# Processing Record 40 of Set 1 | kodiak
# Processing Record 41 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 1 | kruisfontein
# Processing Record 43 of Set 1 | faanui
# Processing Record 44 of Set 1 | hirado
# Processing Record 45 of Set 1 | ilulissat
# Processing Record 46 of Set 1 | santa
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | tuatapere
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | kaohsiung
# Processing Record 1 of Set 2 | lavrentiya
# Processing Record 2 of Set 2 | laguna
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | eyl
# Processing Record 5 of Set 2 | buraydah
# Processing Record 6 of Set 2 | bethel
# Processing Record 7 of Set 2 | saint-philippe
# Processing Record 8 of Set 2 | ribeira grande
# Processing Record 9 of Set 2 | lerwick
# Processing Record 10 of Set 2 | hithadhoo
# Processing Record 11 of Set 2 | nanortalik
# Processing Record 12 of Set 2 | atuona
# Processing Record 13 of Set 2 | maceio
# Processing Record 14 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 2 | ulaanbaatar
# Processing Record 16 of Set 2 | barrow
# Processing Record 17 of Set 2 | esperance
# Processing Record 18 of Set 2 | bluff
# Processing Record 19 of Set 2 | yellowknife
# Processing Record 20 of Set 2 | tateyama
# Processing Record 21 of Set 2 | providencia
# Processing Record 22 of Set 2 | mount pleasant
# Processing Record 23 of Set 2 | norman wells
# Processing Record 24 of Set 2 | chuy
# Processing Record 25 of Set 2 | tessalit
# Processing Record 26 of Set 2 | nargana
# Processing Record 27 of Set 2 | hilo
# Processing Record 28 of Set 2 | coihaique
# Processing Record 29 of Set 2 | saskylakh
# Processing Record 30 of Set 2 | dharchula
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | jalor
# Processing Record 33 of Set 2 | port hardy
# Processing Record 34 of Set 2 | vila velha
# Processing Record 35 of Set 2 | rawson
# Processing Record 36 of Set 2 | tuktoyaktuk
# Processing Record 37 of Set 2 | erenhot
# Processing Record 38 of Set 2 | sinnar
# Processing Record 39 of Set 2 | carnarvon
# Processing Record 40 of Set 2 | kijang
# Processing Record 41 of Set 2 | labelle
# Processing Record 42 of Set 2 | bezhetsk
# Processing Record 43 of Set 2 | longyearbyen
# Processing Record 44 of Set 2 | port elizabeth
# Processing Record 45 of Set 2 | tadine
# Processing Record 46 of Set 2 | mar del plata
# Processing Record 47 of Set 2 | yingkou
# Processing Record 48 of Set 2 | davila
# Processing Record 49 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 2 | klaksvik
# Processing Record 1 of Set 3 | bereda
# Processing Record 2 of Set 3 | kaitangata
# Processing Record 3 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 4 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 5 of Set 3 | saveni
# Processing Record 6 of Set 3 | kalmunai
# Processing Record 7 of Set 3 | rio grande
# Processing Record 8 of Set 3 | new norfolk
# Processing Record 9 of Set 3 | tasiilaq
# Processing Record 10 of Set 3 | kapaa
# Processing Record 11 of Set 3 | oytal
# Processing Record 12 of Set 3 | saint george
# Processing Record 13 of Set 3 | caravelas
# Processing Record 14 of Set 3 | ust-kulom
# Processing Record 15 of Set 3 | salcininkai
# Processing Record 16 of Set 3 | avarua
# Processing Record 17 of Set 3 | kuytun
# Processing Record 18 of Set 3 | dakoro
# Processing Record 19 of Set 3 | pevek
# Processing Record 20 of Set 3 | qaanaaq
# Processing Record 21 of Set 3 | quelimane
# Processing Record 22 of Set 3 | arman
# Processing Record 23 of Set 3 | kolyshley
# Processing Record 24 of Set 3 | castro
# Processing Record 25 of Set 3 | lata
# Processing Record 26 of Set 3 | olafsvik
# Processing Record 27 of Set 3 | ibra
# Processing Record 28 of Set 3 | masallatah
# Processing Record 29 of Set 3 | lompoc
# Processing Record 30 of Set 3 | wewak
# Processing Record 31 of Set 3 | luderitz
# Processing Record 32 of Set 3 | mogadishu
# Processing Record 33 of Set 3 | ville-marie
# Processing Record 34 of Set 3 | la ronge
# Processing Record 35 of Set 3 | mayo
# Processing Record 36 of Set 3 | bubaque
# Processing Record 37 of Set 3 | morehead
# Processing Record 38 of Set 3 | east london
# Processing Record 39 of Set 3 | cayenne
# Processing Record 40 of Set 3 | arraial do cabo
# Processing Record 41 of Set 3 | shingu
# Processing Record 42 of Set 3 | flinders
# Processing Record 43 of Set 3 | vanavara
# Processing Record 44 of Set 3 | sand springs
# Processing Record 45 of Set 3 | businga
# Processing Record 46 of Set 3 | fuxin
# Processing Record 47 of Set 3 | strezhevoy
# Processing Record 48 of Set 3 | namibe
# Processing Record 49 of Set 3 | araxa
# Processing Record 50 of Set 3 | presidencia roque saenz pena
# Processing Record 1 of Set 4 | nantucket
# Processing Record 2 of Set 4 | jojoima
# Processing Record 3 of Set 4 | launceston
# Processing Record 4 of Set 4 | hobart
# Processing Record 5 of Set 4 | karratha
# Processing Record 6 of Set 4 | mandalgovi
# Processing Record 7 of Set 4 | tilichiki
# Processing Record 8 of Set 4 | batagay
# Processing Record 9 of Set 4 | cheney
# Processing Record 10 of Set 4 | sao filipe
# Processing Record 11 of Set 4 | bonavista
# Processing Record 12 of Set 4 | saldanha
# Processing Record 13 of Set 4 | fort nelson
# Processing Record 14 of Set 4 | barguzin
# Processing Record 15 of Set 4 | thompson
# Processing Record 16 of Set 4 | chicama
# Processing Record 17 of Set 4 | talnakh
# Processing Record 18 of Set 4 | jamestown
# Processing Record 19 of Set 4 | atar
# Processing Record 20 of Set 4 | bardiyah
# Processing Record 21 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 4 | asau
# Processing Record 23 of Set 4 | biak
# Processing Record 24 of Set 4 | hambantota
# Processing Record 25 of Set 4 | nisia floresta
# Processing Record 26 of Set 4 | conceicao do araguaia
# Processing Record 27 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 4 | natal
# Processing Record 29 of Set 4 | ingham
# Processing Record 30 of Set 4 | san quintin
# Processing Record 31 of Set 4 | vilyuysk
# Processing Record 32 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 4 | bengkulu
# Processing Record 34 of Set 4 | mahebourg
# Processing Record 35 of Set 4 | ola
# Processing Record 36 of Set 4 | morant bay
# Processing Record 37 of Set 4 | labuhan
# Processing Record 38 of Set 4 | bullhead city
# Processing Record 39 of Set 4 | anna paulowna
# Processing Record 40 of Set 4 | vila
# Processing Record 41 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 42 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 4 | port lincoln
# Processing Record 44 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 4 | salalah
# Processing Record 46 of Set 4 | saurimo
# Processing Record 47 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 48 of Set 4 | belmont
# Processing Record 49 of Set 4 | lebu
# Processing Record 50 of Set 4 | beni mazar
# Processing Record 1 of Set 5 | puerto narino
# Processing Record 2 of Set 5 | thano bula khan
# City not found. Skipping...
# Processing Record 3 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 5 | opuwo
# Processing Record 5 of Set 5 | gamba
# Processing Record 6 of Set 5 | mirnyy
# Processing Record 7 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 8 of Set 5 | souillac
# Processing Record 9 of Set 5 | faya
# Processing Record 10 of Set 5 | mehamn
# Processing Record 11 of Set 5 | banjarmasin
# Processing Record 12 of Set 5 | alindao
# Processing Record 13 of Set 5 | kandi
# Processing Record 14 of Set 5 | burns lake
# Processing Record 15 of Set 5 | kantunilkin
# Processing Record 16 of Set 5 | kuryk
# Processing Record 17 of Set 5 | san cristobal
# Processing Record 18 of Set 5 | khatanga
# Processing Record 19 of Set 5 | ancud
# Processing Record 20 of Set 5 | mana
# Processing Record 21 of Set 5 | tallahassee
# Processing Record 22 of Set 5 | mabaruma
# Processing Record 23 of Set 5 | san lorenzo
# Processing Record 24 of Set 5 | cherskiy
# Processing Record 25 of Set 5 | samarai
# Processing Record 26 of Set 5 | aksarka
# Processing Record 27 of Set 5 | maneadero
# Processing Record 28 of Set 5 | omboue
# Processing Record 29 of Set 5 | coahuayana
# Processing Record 30 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 31 of Set 5 | minab
# Processing Record 32 of Set 5 | punta arenas
# Processing Record 33 of Set 5 | mapimi
# Processing Record 34 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 5 | hamilton
# Processing Record 36 of Set 5 | ambanja
# Processing Record 37 of Set 5 | portree
# Processing Record 38 of Set 5 | sorong
# Processing Record 39 of Set 5 | loja
# Processing Record 40 of Set 5 | haren
# Processing Record 41 of Set 5 | lagoa
# Processing Record 42 of Set 5 | gat
# Processing Record 43 of Set 5 | nanakuli
# Processing Record 44 of Set 5 | yarada
# Processing Record 45 of Set 5 | airai
# Processing Record 46 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 5 | nuzvid
# Processing Record 48 of Set 5 | belyy yar
# Processing Record 49 of Set 5 | sechura
# Processing Record 50 of Set 5 | aswan
# Processing Record 1 of Set 6 | dingle
# Processing Record 2 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 3 of Set 6 | dipkarpaz
# City not found. Skipping...
# Processing Record 4 of Set 6 | portobelo
# Processing Record 5 of Set 6 | moron
# Processing Record 6 of Set 6 | northam
# Processing Record 7 of Set 6 | sao gabriel da cachoeira
# Processing Record 8 of Set 6 | ulladulla
# Processing Record 9 of Set 6 | newport
# Processing Record 10 of Set 6 | ndjole
# Processing Record 11 of Set 6 | grootfontein
# Processing Record 12 of Set 6 | borogontsy
# Processing Record 13 of Set 6 | panarukan
# Processing Record 14 of Set 6 | chacabuco
# Processing Record 15 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 6 | forest
# Processing Record 17 of Set 6 | berezovyy
# Processing Record 18 of Set 6 | great yarmouth
# Processing Record 19 of Set 6 | agira
# Processing Record 20 of Set 6 | yumen
# Processing Record 21 of Set 6 | snasa
# Processing Record 22 of Set 6 | prince rupert
# Processing Record 23 of Set 6 | alofi
# Processing Record 24 of Set 6 | labrea
# Processing Record 25 of Set 6 | talaya
# Processing Record 26 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 6 | kushima
# Processing Record 28 of Set 6 | santa cruz
# Processing Record 29 of Set 6 | manta
# Processing Record 30 of Set 6 | parkes
# Processing Record 31 of Set 6 | oyama
# Processing Record 32 of Set 6 | lingao
# Processing Record 33 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 6 | felidhoo
# City not found. Skipping...
# Processing Record 35 of Set 6 | broome
# Processing Record 36 of Set 6 | waynesville
# Processing Record 37 of Set 6 | yenagoa
# Processing Record 38 of Set 6 | saint-georges
# Processing Record 39 of Set 6 | norrtalje
# Processing Record 40 of Set 6 | ust-ilimsk
# Processing Record 41 of Set 6 | nara
# Processing Record 42 of Set 6 | sorland
# Processing Record 43 of Set 6 | asfi
# Processing Record 44 of Set 6 | myrtle beach
# Processing Record 45 of Set 6 | oshnaviyeh
# Processing Record 46 of Set 6 | chaohu
# Processing Record 47 of Set 6 | ahtopol
# Processing Record 48 of Set 6 | constitucion
# Processing Record 49 of Set 6 | urumqi
# Processing Record 50 of Set 6 | dalen
# Processing Record 1 of Set 7 | cacapava do sul
# Processing Record 2 of Set 7 | new amsterdam
# Processing Record 3 of Set 7 | katsuura
# Processing Record 4 of Set 7 | pala
# Processing Record 5 of Set 7 | pandan
# Processing Record 6 of Set 7 | novyy urgal
# Processing Record 7 of Set 7 | leshukonskoye
# Processing Record 8 of Set 7 | bokoro
# Processing Record 9 of Set 7 | srednekolymsk
# Processing Record 10 of Set 7 | kulhudhuffushi
# Processing Record 11 of Set 7 | narsaq
# Processing Record 12 of Set 7 | progreso
# Processing Record 13 of Set 7 | tera
# Processing Record 14 of Set 7 | nome
# Processing Record 15 of Set 7 | bretigny-sur-orge
# Processing Record 16 of Set 7 | sitka
# Processing Record 17 of Set 7 | mackenzie
# Processing Record 18 of Set 7 | cam ranh
# Processing Record 19 of Set 7 | san juan
# Processing Record 20 of Set 7 | villamontes
# Processing Record 21 of Set 7 | chumikan
# Processing Record 22 of Set 7 | conde
# Processing Record 23 of Set 7 | paamiut
# Processing Record 24 of Set 7 | placido de castro
# Processing Record 25 of Set 7 | hofn
# Processing Record 26 of Set 7 | khasan
# Processing Record 27 of Set 7 | tabas
# Processing Record 28 of Set 7 | tahe
# Processing Record 29 of Set 7 | shunyi
# Processing Record 30 of Set 7 | worland
# Processing Record 31 of Set 7 | hami
# Processing Record 32 of Set 7 | marathon
# Processing Record 33 of Set 7 | banamba
# Processing Record 34 of Set 7 | rocha
# Processing Record 35 of Set 7 | punta alta
# Processing Record 36 of Set 7 | taitung
# Processing Record 37 of Set 7 | ferrol
# Processing Record 38 of Set 7 | bandarbeyla
# Processing Record 39 of Set 7 | henties bay
# Processing Record 40 of Set 7 | ewa beach
# Processing Record 41 of Set 7 | aykhal
# Processing Record 42 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 7 | bukama
# Processing Record 44 of Set 7 | banka
# Processing Record 45 of Set 7 | saint-augustin
# Processing Record 46 of Set 7 | nampula
# Processing Record 47 of Set 7 | saint anthony
# Processing Record 48 of Set 7 | zabol
# Processing Record 49 of Set 7 | seoul
# Processing Record 50 of Set 7 | clyde river
# Processing Record 1 of Set 8 | dubenskiy
# City not found. Skipping...
# Processing Record 2 of Set 8 | pangnirtung
# Processing Record 3 of Set 8 | cabo san lucas
# Processing Record 4 of Set 8 | ust-ishim
# Processing Record 5 of Set 8 | ugoofaaru
# Processing Record 6 of Set 8 | plavinas
# Processing Record 7 of Set 8 | keuruu
# Processing Record 8 of Set 8 | giddalur
# Processing Record 9 of Set 8 | kodinsk
# Processing Record 10 of Set 8 | riyadh
# Processing Record 11 of Set 8 | micheweni
# Processing Record 12 of Set 8 | kleck
# City not found. Skipping...
# Processing Record 13 of Set 8 | evensk
# Processing Record 14 of Set 8 | savelugu
# Processing Record 15 of Set 8 | avera
# Processing Record 16 of Set 8 | north platte
# Processing Record 17 of Set 8 | gornopravdinsk
# Processing Record 18 of Set 8 | liebenburg
# Processing Record 19 of Set 8 | kendari
# Processing Record 20 of Set 8 | palu
# Processing Record 21 of Set 8 | sulangan
# Processing Record 22 of Set 8 | vila franca do campo
# Processing Record 23 of Set 8 | bambanglipuro
# Processing Record 24 of Set 8 | kitimat
# Processing Record 25 of Set 8 | christchurch
# Processing Record 26 of Set 8 | hovd
# Processing Record 27 of Set 8 | am timan
# Processing Record 28 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 29 of Set 8 | anchorage
# Processing Record 30 of Set 8 | luganville
# Processing Record 31 of Set 8 | howard springs
# Processing Record 32 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 8 | san ramon
# Processing Record 34 of Set 8 | colwyn bay
# Processing Record 35 of Set 8 | codrington
# Processing Record 36 of Set 8 | colares
# Processing Record 37 of Set 8 | cidreira
# Processing Record 38 of Set 8 | victoria
# Processing Record 39 of Set 8 | mount gambier
# Processing Record 40 of Set 8 | dukat
# Processing Record 41 of Set 8 | bonthe
# Processing Record 42 of Set 8 | krasnogorskiy
# Processing Record 43 of Set 8 | swift current
# Processing Record 44 of Set 8 | polunochnoye
# Processing Record 45 of Set 8 | chimbote
# Processing Record 46 of Set 8 | college
# Processing Record 47 of Set 8 | fushan
# Processing Record 48 of Set 8 | morges
# Processing Record 49 of Set 8 | san andres
# Processing Record 50 of Set 8 | celestun
# Processing Record 1 of Set 9 | hay river
# Processing Record 2 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 9 | jumla
# Processing Record 4 of Set 9 | parit raja
# Processing Record 5 of Set 9 | atascocita
# Processing Record 6 of Set 9 | hasaki
# Processing Record 7 of Set 9 | kenai
# Processing Record 8 of Set 9 | senador guiomard
# Processing Record 9 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 9 | lieksa
# Processing Record 11 of Set 9 | tocopilla
# Processing Record 12 of Set 9 | port blair
# Processing Record 13 of Set 9 | catamarca
# Processing Record 14 of Set 9 | dindori
# Processing Record 15 of Set 9 | geraldton
# Processing Record 16 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 17 of Set 9 | myitkyina
# Processing Record 18 of Set 9 | port keats
# Processing Record 19 of Set 9 | talara
# Processing Record 20 of Set 9 | lalin
# Processing Record 21 of Set 9 | fomboni
# Processing Record 22 of Set 9 | georgetown
# Processing Record 23 of Set 9 | bousse
# Processing Record 24 of Set 9 | pisco
# Processing Record 25 of Set 9 | iskateley
# Processing Record 26 of Set 9 | tonj
# Processing Record 27 of Set 9 | lokoja
# Processing Record 28 of Set 9 | camopi
# Processing Record 29 of Set 9 | pacasmayo
# Processing Record 30 of Set 9 | mooi river
# City not found. Skipping...
# Processing Record 31 of Set 9 | kahului
# Processing Record 32 of Set 9 | voznesenskoye
# Processing Record 33 of Set 9 | katherine
# Processing Record 34 of Set 9 | kabalo
# Processing Record 35 of Set 9 | pachino
# Processing Record 36 of Set 9 | byron bay
# Processing Record 37 of Set 9 | keflavik
# Processing Record 38 of Set 9 | tamandare
# Processing Record 39 of Set 9 | aktau
# Processing Record 40 of Set 9 | lander
# Processing Record 41 of Set 9 | denpasar
# Processing Record 42 of Set 9 | gravdal
# Processing Record 43 of Set 9 | stornoway
# Processing Record 44 of Set 9 | nuuk
# Processing Record 45 of Set 9 | tay ninh
# Processing Record 46 of Set 9 | moerai
# Processing Record 47 of Set 9 | vardo
# Processing Record 48 of Set 9 | fortuna
# Processing Record 49 of Set 9 | eskilstuna
# Processing Record 50 of Set 9 | verkhnevilyuysk
# Processing Record 1 of Set 10 | otjimbingwe
# Processing Record 2 of Set 10 | gurskoye
# City not found. Skipping...
# Processing Record 3 of Set 10 | farrukhnagar
# Processing Record 4 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 6 of Set 10 | jining
# Processing Record 7 of Set 10 | nanchital
# Processing Record 8 of Set 10 | iberia
# Processing Record 9 of Set 10 | canandaigua
# Processing Record 10 of Set 10 | zhezkazgan
# Processing Record 11 of Set 10 | ciudad guayana
# Processing Record 12 of Set 10 | palmer
# Processing Record 13 of Set 10 | moose factory
# Processing Record 14 of Set 10 | san-pedro
# Processing Record 15 of Set 10 | barra patuca
# Processing Record 16 of Set 10 | kamenka
# Processing Record 17 of Set 10 | jackson
# Processing Record 18 of Set 10 | thinadhoo
# Processing Record 19 of Set 10 | gorontalo
# Processing Record 20 of Set 10 | coquimbo
# Processing Record 21 of Set 10 | kaya
# Processing Record 22 of Set 10 | isangel
# Processing Record 23 of Set 10 | tura
# Processing Record 24 of Set 10 | shimoda
# Processing Record 25 of Set 10 | diu
# Processing Record 26 of Set 10 | teguldet
# Processing Record 27 of Set 10 | tuy hoa
# Processing Record 28 of Set 10 | clarence town
# Processing Record 29 of Set 10 | svetlaya
# Processing Record 30 of Set 10 | los llanos de aridane
# Processing Record 31 of Set 10 | tecpan
# Processing Record 32 of Set 10 | eureka
# Processing Record 33 of Set 10 | volosovo
# Processing Record 34 of Set 10 | bongandanga
# Processing Record 35 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 10 | duobao
# Processing Record 37 of Set 10 | tharad
# Processing Record 38 of Set 10 | roma
# Processing Record 39 of Set 10 | antofagasta
# Processing Record 40 of Set 10 | fairbanks
# Processing Record 41 of Set 10 | porbandar
# Processing Record 42 of Set 10 | clinton
# Processing Record 43 of Set 10 | tambo
# Processing Record 44 of Set 10 | sao joao da barra
# Processing Record 45 of Set 10 | general roca
# Processing Record 46 of Set 10 | hillsborough
# Processing Record 47 of Set 10 | pontianak
# Processing Record 48 of Set 10 | dabakala
# Processing Record 49 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 50 of Set 10 | woodward
# Processing Record 1 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 2 of Set 11 | guajara-mirim
# City not found. Skipping...
# Processing Record 3 of Set 11 | port macquarie
# Processing Record 4 of Set 11 | zelenoborskiy
# Processing Record 5 of Set 11 | necochea
# Processing Record 6 of Set 11 | touros
# Processing Record 7 of Set 11 | jimma
# Processing Record 8 of Set 11 | marfino
# Processing Record 9 of Set 11 | shirdi
# Processing Record 10 of Set 11 | savannah bight
# Processing Record 11 of Set 11 | timra
# Processing Record 12 of Set 11 | issum
# Processing Record 13 of Set 11 | vagay
# Processing Record 14 of Set 11 | adrar
# Processing Record 15 of Set 11 | ocos
# Processing Record 16 of Set 11 | camacha
# Processing Record 17 of Set 11 | axim
# Processing Record 18 of Set 11 | karabuk
# Processing Record 19 of Set 11 | aklavik
# Processing Record 20 of Set 11 | marabba
# Processing Record 21 of Set 11 | sumenep
# Processing Record 22 of Set 11 | lorengau
# Processing Record 23 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 24 of Set 11 | lakes entrance
# Processing Record 25 of Set 11 | black river
# Processing Record 26 of Set 11 | elat
# Processing Record 27 of Set 11 | thai binh
# Processing Record 28 of Set 11 | hashtrud
# Processing Record 29 of Set 11 | ixtapa
# Processing Record 30 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 31 of Set 11 | ertil
# Processing Record 32 of Set 11 | maykain
# City not found. Skipping...
# Processing Record 33 of Set 11 | kaka
# Processing Record 34 of Set 11 | harper
# Processing Record 35 of Set 11 | port hedland
# Processing Record 36 of Set 11 | ballangen
# Processing Record 37 of Set 11 | angoche
# Processing Record 38 of Set 11 | jinchang
# Processing Record 39 of Set 11 | slidell
# Processing Record 40 of Set 11 | high level
# Processing Record 41 of Set 11 | bogorodskoye
# Processing Record 42 of Set 11 | ust-omchug
# Processing Record 43 of Set 11 | praia
# Processing Record 44 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 11 | mahajanga
# Processing Record 46 of Set 11 | shebalino
# Processing Record 47 of Set 11 | sasovo
# Processing Record 48 of Set 11 | maarianhamina
# Processing Record 49 of Set 11 | salym
# Processing Record 50 of Set 11 | abha
# Processing Record 1 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 2 of Set 12 | pogar
# Processing Record 3 of Set 12 | chongwe
# Processing Record 4 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 5 of Set 12 | kyzyl-suu
# Processing Record 6 of Set 12 | awbari
# Processing Record 7 of Set 12 | farmington
# Processing Record 8 of Set 12 | teguise
# Processing Record 9 of Set 12 | ratne
# Processing Record 10 of Set 12 | ponta do sol
# Processing Record 11 of Set 12 | harrisonburg
# Processing Record 12 of Set 12 | brahmapuri
# City not found. Skipping...
# Processing Record 13 of Set 12 | bathsheba
# Processing Record 14 of Set 12 | yeppoon
# Processing Record 15 of Set 12 | bowen
# Processing Record 16 of Set 12 | beisfjord
# Processing Record 17 of Set 12 | mildura
# Processing Record 18 of Set 12 | cabra
# Processing Record 19 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 12 | lokosovo
# Processing Record 21 of Set 12 | nimaparha
# Processing Record 22 of Set 12 | nabire
# Processing Record 23 of Set 12 | puerto escondido
# Processing Record 24 of Set 12 | bilibino
# Processing Record 25 of Set 12 | mount isa
# Processing Record 26 of Set 12 | cascais
# Processing Record 27 of Set 12 | gizo
# Processing Record 28 of Set 12 | klyuchi
# Processing Record 29 of Set 12 | jingcheng
# Processing Record 30 of Set 12 | hat yai
# Processing Record 31 of Set 12 | haapiti
# Processing Record 32 of Set 12 | marrakesh
# Processing Record 33 of Set 12 | komsomolskiy
# Processing Record 34 of Set 12 | batemans bay
# Processing Record 35 of Set 12 | korla
# Processing Record 36 of Set 12 | taphan hin
# Processing Record 37 of Set 12 | balurghat
# Processing Record 38 of Set 12 | port augusta
# Processing Record 39 of Set 12 | rabo de peixe
# Processing Record 40 of Set 12 | solnechnyy
# Processing Record 41 of Set 12 | poum
# Processing Record 42 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 43 of Set 12 | burica
# City not found. Skipping...
# Processing Record 44 of Set 12 | vanimo
# Processing Record 45 of Set 12 | husavik
# Processing Record 46 of Set 12 | roald
# Processing Record 47 of Set 12 | iqaluit
# Processing Record 48 of Set 12 | lekoni
# Processing Record 49 of Set 12 | panaba
# Processing Record 50 of Set 12 | heihe
# Processing Record 1 of Set 13 | banda aceh
# Processing Record 2 of Set 13 | maldonado
# Processing Record 3 of Set 13 | sterling
# Processing Record 4 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 13 | calvinia
# Processing Record 6 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 7 of Set 13 | ust-maya
# Processing Record 8 of Set 13 | guanica
# Processing Record 9 of Set 13 | svobodnyy
# Processing Record 10 of Set 13 | verkhoyansk
# Processing Record 11 of Set 13 | vao
# Processing Record 12 of Set 13 | olavarria
# Processing Record 13 of Set 13 | praia da vitoria
# Processing Record 14 of Set 13 | quatre cocos
# Processing Record 15 of Set 13 | innisfail
# Processing Record 16 of Set 13 | miyang
# Processing Record 17 of Set 13 | yabrud
# Processing Record 18 of Set 13 | chapais
# Processing Record 19 of Set 13 | praya
# Processing Record 20 of Set 13 | kjollefjord
# Processing Record 21 of Set 13 | bilma
# Processing Record 22 of Set 13 | kudahuvadhoo
# Processing Record 23 of Set 13 | nizhnevartovsk
# Processing Record 24 of Set 13 | ye
# City not found. Skipping...
# Processing Record 25 of Set 13 | banmo
# City not found. Skipping...
# Processing Record 26 of Set 13 | agua branca
# Processing Record 27 of Set 13 | ponta delgada
# Processing Record 28 of Set 13 | jieshi
# Processing Record 29 of Set 13 | rosarito
# Processing Record 30 of Set 13 | namatanai
# Processing Record 31 of Set 13 | alyangula
# Processing Record 32 of Set 13 | marawi
# Processing Record 33 of Set 13 | khani
# Processing Record 34 of Set 13 | aleksandrovskiy zavod
# Processing Record 35 of Set 13 | kaeo
# Processing Record 36 of Set 13 | pocone
# Processing Record 37 of Set 13 | ranong
# Processing Record 38 of Set 13 | montmagny
# Processing Record 39 of Set 13 | ilhabela
# Processing Record 40 of Set 13 | comodoro rivadavia
# Processing Record 41 of Set 13 | yulara
# Processing Record 42 of Set 13 | kashi
# Processing Record 43 of Set 13 | aksarayskiy
# Processing Record 44 of Set 13 | abu dhabi
# Processing Record 45 of Set 13 | floriano
# Processing Record 46 of Set 13 | te anau
# Processing Record 47 of Set 13 | waipawa
# Processing Record 48 of Set 13 | marsa matruh
# Processing Record 49 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 50 of Set 13 | brownsville
# Processing Record 1 of Set 14 | bucerias
# Processing Record 2 of Set 14 | ascension
# Processing Record 3 of Set 14 | muravlenko
# Processing Record 4 of Set 14 | meulaboh
# Processing Record 5 of Set 14 | kouroussa
# Processing Record 6 of Set 14 | idlib
# Processing Record 7 of Set 14 | miranorte
# City not found. Skipping...
# Processing Record 8 of Set 14 | tabou
# Processing Record 9 of Set 14 | yeniseysk
# Processing Record 10 of Set 14 | coihueco
# Processing Record 11 of Set 14 | dossor
# Processing Record 12 of Set 14 | marienburg
# Processing Record 13 of Set 14 | trinidad
# Processing Record 14 of Set 14 | jacobina
# Processing Record 15 of Set 14 | cururupu
# Processing Record 16 of Set 14 | rantepao
# Processing Record 17 of Set 14 | calibutbut
# Processing Record 18 of Set 14 | ostrovnoy
# Processing Record 19 of Set 14 | fort dodge
# Processing Record 20 of Set 14 | george
# Processing Record 21 of Set 14 | copiapo
# Processing Record 22 of Set 14 | talakan
# Processing Record 23 of Set 14 | mendoza
# Processing Record 24 of Set 14 | la libertad
# Processing Record 25 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 26 of Set 14 | ithaca
# Processing Record 27 of Set 14 | nemuro
# Processing Record 28 of Set 14 | farsund
# Processing Record 29 of Set 14 | akdagmadeni
# Processing Record 30 of Set 14 | kokopo
# Processing Record 31 of Set 14 | wamba
# Processing Record 32 of Set 14 | luanda
# Processing Record 33 of Set 14 | veracruz
# Processing Record 34 of Set 14 | road town
# Processing Record 35 of Set 14 | sinnamary
# Processing Record 36 of Set 14 | vostok
# Processing Record 37 of Set 14 | cam pha
# City not found. Skipping...
# Processing Record 38 of Set 14 | lephepe
# City not found. Skipping...
# Processing Record 39 of Set 14 | bonfim
# Processing Record 40 of Set 14 | cuyo
# Processing Record 41 of Set 14 | tolaga bay
# Processing Record 42 of Set 14 | aguimes
# Processing Record 43 of Set 14 | kungurtug
# Processing Record 44 of Set 14 | tomatlan
# Processing Record 45 of Set 14 | chiang rai
# Processing Record 46 of Set 14 | cockburn town
# Processing Record 47 of Set 14 | almeirim
# Processing Record 48 of Set 14 | tchaourou
# Processing Record 49 of Set 14 | manakara
# Processing Record 50 of Set 14 | kiruna
# Processing Record 1 of Set 15 | atagay
# Processing Record 2 of Set 15 | dambulla
# Processing Record 3 of Set 15 | minot
# Processing Record 4 of Set 15 | krasnyy kholm
# Processing Record 5 of Set 15 | utete
# Processing Record 6 of Set 15 | anloga
# Processing Record 7 of Set 15 | adre
# Processing Record 8 of Set 15 | half moon bay
# Processing Record 9 of Set 15 | invermere
# Processing Record 10 of Set 15 | beringovskiy
# Processing Record 11 of Set 15 | broken hill
# Processing Record 12 of Set 15 | whitianga
# Processing Record 13 of Set 15 | chalatenango
# Processing Record 14 of Set 15 | outlook
# Processing Record 15 of Set 15 | alcaniz
# Processing Record 16 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 15 | goderich
# Processing Record 18 of Set 15 | el paujil
# Processing Record 19 of Set 15 | uyuni
# Processing Record 20 of Set 15 | flagstaff
# Processing Record 21 of Set 15 | tottori
# Processing Record 22 of Set 15 | oussouye
# Processing Record 23 of Set 15 | sinjar
# Processing Record 24 of Set 15 | russell
# Processing Record 25 of Set 15 | koungou
# Processing Record 26 of Set 15 | lima
# Processing Record 27 of Set 15 | emmanouil pappas
# Processing Record 28 of Set 15 | lazaro cardenas
# Processing Record 29 of Set 15 | tulum
# Processing Record 30 of Set 15 | klaeng
# Processing Record 31 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 32 of Set 15 | jabiru
# City not found. Skipping...
# Processing Record 33 of Set 15 | amapa
# Processing Record 34 of Set 15 | ketchikan
# Processing Record 35 of Set 15 | jahrom
# City not found. Skipping...
# Processing Record 36 of Set 15 | garissa
# Processing Record 37 of Set 15 | porto santo
# Processing Record 38 of Set 15 | aljezur
# Processing Record 39 of Set 15 | linjiang
# Processing Record 40 of Set 15 | ayan
# Processing Record 41 of Set 15 | haines junction
# Processing Record 42 of Set 15 | ampanihy
# Processing Record 43 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 44 of Set 15 | krasnoselkup
# Processing Record 45 of Set 15 | kieta
# Processing Record 46 of Set 15 | padang
# Processing Record 47 of Set 15 | san policarpo
# Processing Record 48 of Set 15 | ahuimanu
# Processing Record 49 of Set 15 | peterhead
# Processing Record 50 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 1 of Set 16 | ceres
# Processing Record 2 of Set 16 | seoni
# Processing Record 3 of Set 16 | baykit
# Processing Record 4 of Set 16 | may pen
# Processing Record 5 of Set 16 | whitley bay
# Processing Record 6 of Set 16 | aranos
# Processing Record 7 of Set 16 | tabanan
# Processing Record 8 of Set 16 | ambon
# Processing Record 9 of Set 16 | wabash
# Processing Record 10 of Set 16 | santa rosa
# Processing Record 11 of Set 16 | zhytomyr
# Processing Record 12 of Set 16 | hameenlinna
# Processing Record 13 of Set 16 | kefamenanu
# Processing Record 14 of Set 16 | south hill
# Processing Record 15 of Set 16 | biltine
# Processing Record 16 of Set 16 | formoso do araguaia
# City not found. Skipping...
# Processing Record 17 of Set 16 | two rivers
# Processing Record 18 of Set 16 | saravan
# Processing Record 19 of Set 16 | santa isabel do rio negro
# Processing Record 20 of Set 16 | roccastrada
# Processing Record 21 of Set 16 | mutare
# Processing Record 22 of Set 16 | weihai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Upernavik  72.7868  -56.1549     37.94        90          79       14.94
# 1    Jaguarao -32.5661  -53.3758     62.96        73          59       10.49
# 2  Chokurdakh  70.6333  147.9167     52.09        61         100        6.82
# 3    Kallaste  58.6550   27.1592     71.83        52          89       10.69
# 4       Pasni  25.2631   63.4710     84.38        85          78       12.64
# 5  Butaritari   3.0707  172.7902     81.75        76         100       14.79
# 6     Mataura -46.1927  168.8643     43.48        84         100       10.67
# 7   Grindavik  63.8424  -22.4338     50.47       100         100       34.52
# 8       Tiksi  71.6872  128.8694     46.78        74          99       10.65
# 9       Vaini -21.2000 -175.2000     69.96        78          20        8.05
#
#   Country                 Date      Current Description
# 0      GL  2022-07-07 14:06:20            broken clouds
# 1      BR  2022-07-07 14:06:21            broken clouds
# 2      RU  2022-07-07 14:06:21          overcast clouds
# 3      EE  2022-07-07 14:06:21          overcast clouds
# 4      PK  2022-07-07 14:06:22            broken clouds
# 5      KI  2022-07-07 14:06:22               light rain
# 6      NZ  2022-07-07 14:06:22          overcast clouds
# 7      IS  2022-07-07 14:06:23  light intensity drizzle
# 8      RU  2022-07-07 14:06:23          overcast clouds
# 9      TO  2022-07-07 14:06:23               few clouds

# %%
city_data_df = city_data_df[['City','Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']]

city_data_df.head(10)
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 0   Upernavik      GL  2022-07-07 14:06:20  72.7868  -56.1549     37.94
# 1    Jaguarao      BR  2022-07-07 14:06:21 -32.5661  -53.3758     62.96
# 2  Chokurdakh      RU  2022-07-07 14:06:21  70.6333  147.9167     52.09
# 3    Kallaste      EE  2022-07-07 14:06:21  58.6550   27.1592     71.83
# 4       Pasni      PK  2022-07-07 14:06:22  25.2631   63.4710     84.38
# 5  Butaritari      KI  2022-07-07 14:06:22   3.0707  172.7902     81.75
# 6     Mataura      NZ  2022-07-07 14:06:22 -46.1927  168.8643     43.48
# 7   Grindavik      IS  2022-07-07 14:06:23  63.8424  -22.4338     50.47
# 8       Tiksi      RU  2022-07-07 14:06:23  71.6872  128.8694     46.78
# 9       Vaini      TO  2022-07-07 14:06:23 -21.2000 -175.2000     69.96
#
#    Humidity  Cloudiness  Wind Speed      Current Description
# 0        90          79       14.94            broken clouds
# 1        73          59       10.49            broken clouds
# 2        61         100        6.82          overcast clouds
# 3        52          89       10.69          overcast clouds
# 4        85          78       12.64            broken clouds
# 5        76         100       14.79               light rain
# 6        84         100       10.67          overcast clouds
# 7       100         100       34.52  light intensity drizzle
# 8        74          99       10.65          overcast clouds
# 9        78          20        8.05               few clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
